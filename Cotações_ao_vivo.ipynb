# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoASiq/CotacoesAoVivo/blob/main/Cota%C3%A7%C3%B5es_ao_vivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.54)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
import yfinance as yf

# Obter o preço em tempo real da Apple
ticker = yf.Ticker("BTC-USD")
preco_atual = ticker.info['regularMarketPrice']
print(preco_atual)
# Out:
# 82850.02

# %%
import time
import datetime
import pandas as pd

# %%
n = 60

# %%
tempo = time.time() + 60*n

# %%
a = 0
df = pd.DataFrame(columns = ['horas', 'Preço'])
while time.time() < tempo:
  preco_atual = ticker.info['regularMarketPrice']
  tempoReal = datetime.datetime.fromtimestamp(time.time())
  tempoReal = tempoReal.strftime('%d/%m/%Y %H:%M:%S')
  d = {'horas': tempoReal, 'Preço': preco_atual}
  linha = pd.DataFrame(data = d, index = [a] )
  a += 1
  df = pd.concat([df, linha], ignore_index= True)
  time.sleep(5)
  print(d)
# Out:
# <ipython-input-40-fe633ce9237f>:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, linha], ignore_index= True)
# {'horas': '12/03/2025 00:54:12', 'Preço': 82850.02}
# {'horas': '12/03/2025 00:54:17', 'Preço': 82850.02}
# {'horas': '12/03/2025 00:54:22', 'Preço': 82850.02}
# {'horas': '12/03/2025 00:54:27', 'Preço': 82850.02}
# {'horas': '12/03/2025 00:54:32', 'Preço': 82850.02}
# {'horas': '12/03/2025 00:54:37', 'Preço': 82850.02}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-fe633ce9237f> in <cell line: 0>()
#       9   a += 1
#      10   df = pd.concat([df, linha], ignore_index= True)
# ---> 11   time.sleep(5)
#      12   print(d)
#
# KeyboardInterrupt:

# %%
k = yf.Ticker('KLBN11.SA')

# %%
k.info
# Out:
# {'address1': 'Avenida Brigadeiro Faria Lima, 3600',
#  'address2': '3rd, 4th and 5th Floors Itaim Bibi',
#  'city': 'São Paulo',
#  'state': 'SP',
#  'zip': '04538-132',
#  'country': 'Brazil',
#  'phone': '55 11 3046 8401',
#  'website': 'https://www.klabin.com.br',
#  'industry': 'Paper & Paper Products',
#  'industryKey': 'paper-paper-products',
#  'industryDisp': 'Paper & Paper Products',
#  'sector': 'Basic Materials',
#  'sectorKey': 'basic-materials',
#  'sectorDisp': 'Basic Materials',
#  'longBusinessSummary': 'Klabin S.A., together with its subsidiaries, produces and exports packaging paper and sustainable paper packaging solutions in Brazil and internationally. The company engages in the planting of pine and eucalyptus; and forestry management business. It also produces and sells hardwood (eucalyptus), softwood (pine), and fluffed pulp; and paperboard, sackraft, Kraftliner paper, and recycled paper. In addition, the company offers industrial bags, corrugated boxes, and other packaging products. Klabin S.A. was founded in 1899 and is headquartered in São Paulo, Brazil.',
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Cristiano Cardoso Teixeira',
#    'title': 'CEO, General Director & Member of Executive Board',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Marcos Paulo Conde Ivo',
#    'title': 'Chief Financial & Investor Relations Officer and Member of Executive Board',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Ana Cristina Barcellos Rodrigues',
#    'title': 'Director of People & Management',
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 19.82,
#  'open': 0.0,
#  'dayLow': 0.0,
#  'dayHigh': 0.0,
#  'regularMarketPreviousClose': 19.82,
#  'regularMarketOpen': 0.0,
#  'regularMarketDayLow': 0.0,
#  'regularMarketDayHigh': 0.0,
#  'dividendRate': 0.18,
#  'dividendYield': 0.9,
#  'exDividendDate': 1741219200,
#  'fiveYearAvgDividendYield': 3.11,
#  'beta': 0.454,
#  'trailingPE': 29.364597,
#  'forwardPE': 10.109375,
#  'volume': 0,
#  'regularMarketVolume': 0,
#  'averageVolume': 4737320,
#  'averageVolume10days': 4925600,
#  'averageDailyVolume10Day': 4925600,
#  'bid': 19.48,
#  'ask': 19.54,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 125959061504,
#  'fiftyTwoWeekLow': 0.0,
#  'fiftyTwoWeekHigh': 24.05,
#  'priceToSalesTrailing12Months': 6.4114356,
#  'fiftyDayAverage': 21.6576,
#  'twoHundredDayAverage': 21.4223,
#  'trailingAnnualDividendRate': 0.267,
#  'trailingAnnualDividendYield': 0.013471241,
#  'currency': 'BRL',
#  'tradeable': False,
#  'enterpriseValue': 156510240768,
#  'profitMargins': 0.0932,
#  'floatShares': 4623768866,
#  'sharesOutstanding': 1215910016,
#  'heldPercentInsiders': 0.0,
#  'heldPercentInstitutions': 0.29151,
#  'impliedSharesOutstanding': 6489390080,
#  'bookValue': 1.094,
#  'priceToBook': 17.742231,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1735603200,
#  'earningsQuarterlyGrowth': -0.369,
#  'netIncomeToCommon': 1831000064,
#  'trailingEps': 0.661,
#  'forwardEps': 1.92,
#  'lastSplitFactor': '11:10',
#  'lastSplitDate': 1715040000,
#  'enterpriseToRevenue': 7.967,
#  'enterpriseToEbitda': 21.246,
#  '52WeekChange': -0.025826633,
#  'SandP52WeekChange': 0.0848825,
#  'lastDividendValue': 0.044413,
#  'lastDividendDate': 1741219200,
#  'quoteType': 'EQUITY',
#  'currentPrice': 19.41,
#  'targetHighPrice': 33.0,
#  'targetLowPrice': 22.0,
#  'targetMeanPrice': 27.6,
#  'targetMedianPrice': 28.5,
#  'recommendationMean': 2.14286,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 14,
#  'totalCash': 7530208256,
#  'totalCashPerShare': 1.239,
#  'ebitda': 7366554112,
#  'totalDebt': 41562439680,
#  'quickRatio': 1.48,
#  'currentRatio': 1.929,
#  'totalRevenue': 19645999104,
#  'debtToEquity': 481.203,
#  'revenuePerShare': 3.232,
#  'returnOnAssets': 0.037049998,
#  'returnOnEquity': 0.18301001,
#  'grossProfits': 6302000128,
#  'freeCashflow': -4716692992,
#  'operatingCashflow': 7425327104,
#  'earningsGrowth': -0.371,
#  'revenueGrowth': 0.173,
#  'grossMargins': 0.32077998,
#  'ebitdaMargins': 0.37495998,
#  'operatingMargins': 0.13628,
#  'financialCurrency': 'BRL',
#  'symbol': 'KLBN11.SA',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'LOW',
#  'corporateActions': [],
#  'regularMarketTime': 1741723663,
#  'exchange': 'SAO',
#  'messageBoardId': 'finmb_3800060',
#  'exchangeTimezoneName': 'America/Sao_Paulo',
#  'exchangeTimezoneShortName': 'BRT',
#  'gmtOffSetMilliseconds': -10800000,
#  'market': 'br_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': -2.0686169,
#  'regularMarketPrice': 19.41,
#  'shortName': 'KLABIN S/A  UNT ED  N2',
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 1390478400000,
#  'regularMarketChange': -0.40999985,
#  'regularMarketDayRange': '0.0 - 0.0',
#  'fullExchangeName': 'São Paulo',
#  'averageDailyVolume3Month': 4737320,
#  'fiftyTwoWeekLowChange': 19.41,
#  'fiftyTwoWeekRange': '0.0 - 24.05',
#  'fiftyTwoWeekHighChange': -4.6399994,
#  'fiftyTwoWeekHighChangePercent': -0.19293137,
#  'fiftyTwoWeekChangePercent': -2.5826633,
#  'earningsTimestamp': 1746617400,
#  'earningsTimestampStart': 1746617400,
#  'earningsTimestampEnd': 1746617400,
#  'earningsCallTimestampStart': 1746701940,
#  'earningsCallTimestampEnd': 1746701940,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 0.661,
#  'epsForward': 1.92,
#  'epsCurrentYear': 1.5446,
#  'priceEpsCurrentYear': 12.56636,
#  'longName': 'Klabin S.A.',
#  'fiftyDayAverageChange': -2.2476006,
#  'fiftyDayAverageChangePercent': -0.10377884,
#  'twoHundredDayAverageChange': -2.0123005,
#  'twoHundredDayAverageChangePercent': -0.09393485,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 15,
#  'averageAnalystRating': '2.1 - Buy',
#  'cryptoTradeable': False,
#  'marketState': 'POSTPOST',
#  'trailingPegRatio': None}

# %%
klb = k.history(period='max')

# %%
klb.head()
# Out:
#                                Open      High       Low     Close  Volume  Dividends  Stock Splits
# Date
# 2014-01-23 00:00:00-02:00  6.790827  6.790827  6.790827  6.790827   19250        0.0           0.0
# 2014-01-24 00:00:00-02:00  6.790827  6.790827  6.790827  6.790827       0        0.0           0.0
# 2014-01-27 00:00:00-02:00  6.790827  6.790827  6.790827  6.790827       0        0.0           0.0
# 2014-01-28 00:00:00-02:00  7.334373  7.334373  7.170153  7.277706   95150        0.0           0.0
# 2014-01-29 00:00:00-02:00  7.089199  7.147022  7.086886  7.141240   72600        0.0           0.0

# %%
klb.Dividends.plot();

# %%
klb.Close.plot();

# %%
klb.shape
# Out:
# (2767, 7)

# %%
klb.Dividends.iloc[2000:2760].plot();

# %%
k.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2014-03-21 00:00:00-03:00   0.089391           0.0
# 2014-03-25 00:00:00-03:00   0.000000           5.0
# 2014-08-12 00:00:00-03:00   0.150818           0.0
# 2014-11-11 00:00:00-02:00   0.089335           0.0
# 2015-03-20 00:00:00-03:00   0.101236           0.0
# 2015-03-24 00:00:00-03:00   0.101236           0.0
# 2015-07-28 00:00:00-03:00   0.169709           0.0
# 2015-10-28 00:00:00-02:00   0.104205           0.0
# 2016-02-04 00:00:00-02:00   0.119155           0.0
# 2016-05-02 00:00:00-03:00   0.101692           0.0
# 2016-08-01 00:00:00-03:00   0.107195           0.0
# 2016-11-04 00:00:00-02:00   0.116149           0.0
# 2017-02-07 00:00:00-02:00   0.129205           0.0
# 2017-05-05 00:00:00-03:00   0.057568           0.0
# 2017-08-02 00:00:00-03:00   0.118115           0.0
# 2017-11-03 00:00:00-02:00   0.148884           0.0
# 2018-02-07 00:00:00-02:00   0.147879           0.0
# 2018-05-03 00:00:00-03:00   0.131270           0.0
# 2018-08-06 00:00:00-03:00   0.152861           0.0
# 2018-11-05 00:00:00-02:00   0.293633           0.0
# 2018-12-21 00:00:00-02:00   0.215905           0.0
# 2019-02-13 00:00:00-02:00   0.017272           0.0
# 2019-05-07 00:00:00-03:00   0.173358           0.0
# 2019-08-09 00:00:00-03:00   0.165595           0.0
# 2019-11-07 00:00:00-03:00   0.253569           0.0
# 2019-12-23 00:00:00-03:00   0.172496           0.0
# 2020-02-11 00:00:00-03:00   0.019836           0.0
# 2021-11-01 00:00:00-03:00   0.332702           0.0
# 2022-02-15 00:00:00-03:00   0.312013           0.0
# 2022-05-09 00:00:00-03:00   0.285833           0.0
# 2022-08-02 00:00:00-03:00   0.329624           0.0
# 2022-11-01 00:00:00-03:00   0.414720           0.0
# 2022-11-03 00:00:00-03:00   0.255358           0.0
# 2022-12-21 00:00:00-03:00   0.029741           0.0
# 2023-02-14 00:00:00-03:00   0.285019           0.0
# 2023-05-08 00:00:00-03:00   0.320633           0.0
# 2023-08-07 00:00:00-03:00   0.221618           0.0
# 2023-10-30 00:00:00-03:00   0.262839           0.0
# 2023-12-22 00:00:00-03:00   0.140896           0.0
# 2024-02-16 00:00:00-03:00   0.158201           0.0
# 2024-05-06 00:00:00-03:00   0.271398           0.0
# 2024-05-07 00:00:00-03:00   0.000000           1.1
# 2024-08-06 00:00:00-03:00   0.337195           0.0
# 2024-11-12 00:00:00-03:00   0.298538           0.0
# 2024-12-17 00:00:00-03:00   0.212196           0.0
# 2025-03-06 00:00:00-03:00   0.044413           0.0

# %%
k.dividends.tail()
# Out:
# Date
# 2024-05-06 00:00:00-03:00    0.271398
# 2024-08-06 00:00:00-03:00    0.337195
# 2024-11-12 00:00:00-03:00    0.298538
# 2024-12-17 00:00:00-03:00    0.212196
# 2025-03-06 00:00:00-03:00    0.044413
# Name: Dividends, dtype: float64

# %%
k.dividends.head()
# Out:
# Date
# 2014-03-21 00:00:00-03:00    0.089391
# 2014-08-12 00:00:00-03:00    0.150818
# 2014-11-11 00:00:00-02:00    0.089335
# 2015-03-20 00:00:00-03:00    0.101236
# 2015-03-24 00:00:00-03:00    0.101236
# Name: Dividends, dtype: float64

# %%
k.financials
# Out:
#                                                        2024-12-31  ...   2020-12-31
# Tax Effect Of Unusual Items                            72883493.1  ...          NaN
# Tax Rate For Calcs                                         0.0981  ...          NaN
# Normalized EBITDA                                    8657724000.0  ...          NaN
# Total Unusual Items                                   742951000.0  ...          NaN
# Total Unusual Items Excluding Goodwill                742951000.0  ...          NaN
# Net Income From Continuing Operation Net Minori...   1831011000.0  ...          NaN
# Reconciled Depreciation                              3963554000.0  ...          NaN
# Reconciled Cost Of Revenue                          12273741000.0  ...          NaN
# EBITDA                                               9400675000.0  ...          NaN
# EBIT                                                 5437121000.0  ...          NaN
# Net Interest Income                                 -3436913000.0  ...          NaN
# Interest Expense                                     3167441000.0  ...          NaN
# Interest Income                                        29275000.0  ...          NaN
# Normalized Income                                    1160943493.1  ...          NaN
# Net Income From Continuing And Discontinued Ope...   1831011000.0  ...          NaN
# Total Expenses                                      15037071000.0  ...          NaN
# Rent Expense Supplemental                                     NaN  ...  201667000.0
# Diluted NI Availto Com Stockholders                  1831011000.0  ...          NaN
# Net Income Common Stockholders                       1831011000.0  ...          NaN
# Otherunder Preferred Stock Dividend                           0.0  ...          NaN
# Net Income                                           1831011000.0  ...          NaN
# Minority Interests                                   -215934000.0  ...          NaN
# Net Income Including Noncontrolling Interests        2046945000.0  ...          NaN
# Net Income Continuous Operations                     2046945000.0  ...          NaN
# Tax Provision                                         222735000.0  ...          NaN
# Pretax Income                                        2269680000.0  ...          NaN
# Other Non Operating Income Expenses                  -154540000.0  ...          NaN
# Special Income Charges                                -26692000.0  ...          NaN
# Other Special Charges                                  26692000.0  ...          NaN
# Restructuring And Mergern Acquisition                         NaN  ... -206061000.0
# Net Non Operating Interest Income Expense           -3436913000.0  ...          NaN
# Total Other Finance Cost                              298747000.0  ...          NaN
# Interest Expense Non Operating                       3167441000.0  ...          NaN
# Interest Income Non Operating                          29275000.0  ...          NaN
# Operating Income                                     4608193000.0  ...          NaN
# Operating Expense                                    2763330000.0  ...          NaN
# Other Operating Expenses                               63267000.0  ...          NaN
# Depreciation And Amortization In Income Statement      67650000.0  ...          NaN
# Depreciation Income Statement                          67650000.0  ...          NaN
# Selling General And Administration                   1924332000.0  ...          NaN
# Selling And Marketing Expense                        1449491000.0  ...          NaN
# General And Administrative Expense                    474841000.0  ...          NaN
# Rent And Landing Fees                                         NaN  ...  201667000.0
# Gross Profit                                         7371523000.0  ...          NaN
# Cost Of Revenue                                     12273741000.0  ...          NaN
# Total Revenue                                       19645264000.0  ...          NaN
# Operating Revenue                                   19645264000.0  ...          NaN
#
# [47 rows x 5 columns]

# %%
k.quarterly_balance_sheet
# Out:
#                                                      2024-12-31  ... 2023-06-30
# Treasury Shares Number                              100400464.0  ...        NaN
# Ordinary Shares Number                             6079281567.0  ...        NaN
# Share Issued                                       6179682031.0  ...        NaN
# Net Debt                                          32968066000.0  ...        NaN
# Total Debt                                        41562440000.0  ...        NaN
# ...                                                         ...  ...        ...
# Cash Cash Equivalents And Short Term Investments   7530208000.0  ...        NaN
# Other Short Term Investments                        794037000.0  ...        NaN
# Cash And Cash Equivalents                          6736171000.0  ...        NaN
# Cash Equivalents                                   5667228000.0  ...        NaN
# Cash Financial                                     1068943000.0  ...        NaN
#
# [81 rows x 7 columns]

# %%
k.cashflow
# Out:
#                                            2024-12-31    2023-12-31  ...    2021-12-31   2020-12-31
# Free Cash Flow                           3876918000.0  2030367000.0  ...  1013557000.0          NaN
# Repayment Of Debt                       -1233587000.0 -2185019000.0  ... -1096665000.0          NaN
# Issuance Of Debt                         3224981000.0  7526918000.0  ...  2718480000.0          NaN
# Issuance Of Capital Stock                  22567000.0    29367000.0  ...    18946000.0          NaN
# Capital Expenditure                     -3548409000.0 -4714947000.0  ... -3877692000.0          NaN
# End Cash Position                        6736171000.0  9558829000.0  ...  6405200000.0          NaN
# Beginning Cash Position                  9558829000.0  4683945000.0  ...  5208830000.0          NaN
# Effect Of Exchange Rate Changes           788490000.0  -298493000.0  ...           NaN          NaN
# Changes In Cash                         -3611148000.0  5173377000.0  ...  1196370000.0          NaN
# Financing Cash Flow                     -2432792000.0  1573562000.0  ...   -19024000.0          NaN
# Net Other Financing Charges                50000000.0   105000000.0  ...   367800000.0          NaN
# Interest Paid Cff                       -2191872000.0 -1890575000.0  ... -1203477000.0          NaN
# Cash Dividends Paid                     -1562624000.0 -1358000000.0  ...  -402000000.0          NaN
# Common Stock Dividend Paid                        NaN           NaN  ...           NaN -223000000.0
# Net Common Stock Issuance                  22567000.0    29367000.0  ...    18946000.0          NaN
# Common Stock Issuance                      22567000.0    29367000.0  ...    18946000.0          NaN
# Net Issuance Payments Of Debt            1991394000.0  5341899000.0  ...  1621815000.0          NaN
# Net Long Term Debt Issuance              1991394000.0  5341899000.0  ...  1621815000.0          NaN
# Long Term Debt Payments                 -1233587000.0 -2185019000.0  ... -1096665000.0          NaN
# Long Term Debt Issuance                  3224981000.0  7526918000.0  ...  2718480000.0          NaN
# Investing Cash Flow                     -8603683000.0 -3145499000.0  ... -3675855000.0          NaN
# Net Other Investing Changes             -6269399000.0    46747000.0  ...   181298000.0          NaN
# Dividends Received Cfi                     13767000.0    25173000.0  ...    20539000.0          NaN
# Net Investment Purchase And Sale         1200358000.0  1497528000.0  ...           NaN          NaN
# Sale Of Investment                       1200358000.0  1497528000.0  ...           NaN          NaN
# Purchase Of Investment                            0.0           0.0  ...           NaN          NaN
# Net Business Purchase And Sale                    0.0           0.0  ...           0.0          NaN
# Sale Of Business                                  0.0           0.0  ...           0.0          NaN
# Purchase Of Business                              NaN           NaN  ...           0.0 -388000000.0
# Net PPE Purchase And Sale               -2357228000.0 -3458882000.0  ... -3877692000.0          NaN
# Purchase Of PPE                         -2357228000.0 -3458882000.0  ... -3877692000.0          NaN
# Capital Expenditure Reported            -1191181000.0 -1256065000.0  ...           NaN -624870000.0
# Operating Cash Flow                      7425327000.0  6745314000.0  ...  4891249000.0          NaN
# Taxes Refund Paid                        -489114000.0  -167703000.0  ...  -506606000.0          NaN
# Change In Working Capital                 612701000.0  -399179000.0  ... -1289634000.0          NaN
# Change In Other Current Liabilities        22630000.0    74229000.0  ...   279161000.0          NaN
# Change In Other Current Assets            383543000.0    42410000.0  ...  -705241000.0          NaN
# Change In Payable                       -1724066000.0  -913146000.0  ...  -338325000.0          NaN
# Change In Inventory                      1181607000.0   580408000.0  ...  -633327000.0          NaN
# Change In Receivables                     748987000.0  -183080000.0  ...    54545000.0          NaN
# Other Non Cash Items                     1847593000.0  1915848000.0  ...   139707000.0          NaN
# Provisionand Write Offof Assets            40055000.0    92321000.0  ...    -6857000.0          NaN
# Deferred Tax                              338656000.0     6734000.0  ...   515168000.0          NaN
# Depreciation And Amortization            3963554000.0  3326582000.0  ...  2696341000.0          NaN
# Depreciation                             3963554000.0  3326582000.0  ...  2696341000.0          NaN
# Gain Loss On Investment Securities      -1452085000.0 -1910277000.0  ...     6224000.0          NaN
# Net Foreign Currency Exchange Gain Loss   292642000.0    87057000.0  ...   -42356000.0          NaN
# Gain Loss On Sale Of PPE                   26692000.0    -5438000.0  ...           NaN          NaN
# Net Income From Continuing Operations    2269680000.0  3814057000.0  ...  3404874000.0          NaN
#
# [49 rows x 5 columns]

# %%
k.quarterly_cashflow
# Out:
#                                            2024-12-31     2024-09-30  ...   2023-09-30   2023-06-30
# Free Cash Flow                          -1833672000.0   2841525000.0  ...          NaN          NaN
# Repayment Of Debt                          25666000.0   -874663000.0  ...          NaN          NaN
# Issuance Of Debt                         1500000000.0    -75414000.0  ...          NaN          NaN
# Issuance Of Capital Stock                     -1000.0         1000.0  ...          NaN          NaN
# Capital Expenditure                      -897155000.0   -807905000.0  ...          NaN          NaN
# End Cash Position                        6736171000.0   6668718000.0  ...          NaN          NaN
# Beginning Cash Position                  6668718000.0  11904719000.0  ...          NaN          NaN
# Changes In Cash                          -624514000.0  -5332524000.0  ...          NaN          NaN
# Financing Cash Flow                       -74240000.0  -1824632000.0  ...          NaN          NaN
# Net Other Financing Charges                       0.0            0.0  ...          NaN          NaN
# Interest Paid Cff                        -724285000.0   -382235000.0  ...          NaN          NaN
# Cash Dividends Paid                      -408471000.0   -461153000.0  ...          NaN          NaN
# Net Common Stock Issuance                     -1000.0         1000.0  ...          NaN          NaN
# Common Stock Issuance                         -1000.0         1000.0  ...          NaN          NaN
# Net Issuance Payments Of Debt            1525666000.0   -950077000.0  ...          NaN          NaN
# Net Long Term Debt Issuance              1525666000.0   -950077000.0  ...          NaN          NaN
# Long Term Debt Payments                    25666000.0   -874663000.0  ...          NaN          NaN
# Long Term Debt Issuance                  1500000000.0    -75414000.0  ...          NaN          NaN
# Investing Cash Flow                       386243000.0  -7157322000.0  ...          NaN          NaN
# Net Other Investing Changes                78705000.0  -6351967000.0  ...          NaN          NaN
# Dividends Received Cfi                      4335000.0      2550000.0  ...          NaN          NaN
# Net Business Purchase And Sale                    0.0            0.0  ...          NaN          NaN
# Purchase Of Business                              NaN            0.0  ...          0.0          0.0
# Net PPE Purchase And Sale                 294026000.0   -807905000.0  ...          NaN          NaN
# Sale Of PPE                                       NaN            NaN  ...          NaN   61983000.0
# Purchase Of PPE                           294026000.0   -807905000.0  ...          NaN          NaN
# Capital Expenditure Reported                      NaN            NaN  ...  438526000.0 -292341000.0
# Operating Cash Flow                      -936517000.0   3649430000.0  ...          NaN          NaN
# Taxes Refund Paid                        -129026000.0   -174678000.0  ...          NaN          NaN
# Change In Working Capital                -370742000.0     62610000.0  ...          NaN          NaN
# Change In Other Current Liabilities       251837000.0   -543131000.0  ...          NaN          NaN
# Change In Other Current Assets             76682000.0    246262000.0  ...          NaN          NaN
# Change In Payable                        -583854000.0    -20769000.0  ...          NaN          NaN
# Change In Inventory                       491836000.0    433661000.0  ...          NaN          NaN
# Change In Receivables                    -491024000.0   -183609000.0  ...          NaN          NaN
# Other Non Cash Items                    -1634147000.0   1529242000.0  ...          NaN          NaN
# Provisionand Write Offof Assets             8438000.0     18192000.0  ...          NaN          NaN
# Deferred Tax                               42844000.0            NaN  ...   25060000.0  218447000.0
# Depreciation And Amortization            1103818000.0   1013796000.0  ...          NaN          NaN
# Depreciation                             1103818000.0   1013796000.0  ...          NaN          NaN
# Gain Loss On Investment Securities      -1444421000.0    -42351000.0  ...          NaN          NaN
# Net Foreign Currency Exchange Gain Loss  1083769000.0    162503000.0  ...          NaN          NaN
# Net Income From Continuing Operations     394018000.0    817170000.0  ...          NaN          NaN
#
# [43 rows x 7 columns]

# %%
k.major_holders
# Out:
# Breakdown                         Value
# insidersPercentHeld             0.00000
# institutionsPercentHeld         0.29151
# institutionsFloatPercentHeld    0.29152
# institutionsCount             302.00000

# %%
k.institutional_holders
# Out:
#   Date Reported                                             Holder  ...      Value  pctChange
# 0    2024-12-31  Price (T.Rowe) Emerging Markets Discovery Stoc...  ...  411373789     0.1816
# 1    2024-12-31  Price (T.Rowe) Emerging Markets Discovery Stoc...  ...  275311243     0.0061
# 2    2024-10-31  Vanguard International Stock Index-Total Intl ...  ...  223665213    -0.0647
# 3    2024-12-31       Price (T.Rowe) Emerging Markets Equity Trust  ...  223281496     0.4324
# 4    2024-10-31  Vanguard International Stock Index-Emerging Ma...  ...  206650717    -0.0850
# 5    2024-12-31         Price (T.Rowe) Emerging Markets Stock Fund  ...  198401623     0.1805
# 6    2024-12-31        Price (T.Rowe) International Discovery Fund  ...  188235771     0.0000
# 7    2024-11-30                           iShares MSCI Brazil  ETF  ...  177425876     0.0000
# 8    2024-11-30             iShares Core MSCI Emerging Markets ETF  ...  142475590     0.0049
# 9    2024-10-31         DFA Emerging Markets Core Equity Portfolio  ...  101112065     0.0000
#
# [10 rows x 6 columns]

# %%
k.income_stmt
# Out:
#                                                        2024-12-31  ...   2020-12-31
# Tax Effect Of Unusual Items                            72883493.1  ...          NaN
# Tax Rate For Calcs                                         0.0981  ...          NaN
# Normalized EBITDA                                    8657724000.0  ...          NaN
# Total Unusual Items                                   742951000.0  ...          NaN
# Total Unusual Items Excluding Goodwill                742951000.0  ...          NaN
# Net Income From Continuing Operation Net Minori...   1831011000.0  ...          NaN
# Reconciled Depreciation                              3963554000.0  ...          NaN
# Reconciled Cost Of Revenue                          12273741000.0  ...          NaN
# EBITDA                                               9400675000.0  ...          NaN
# EBIT                                                 5437121000.0  ...          NaN
# Net Interest Income                                 -3436913000.0  ...          NaN
# Interest Expense                                     3167441000.0  ...          NaN
# Interest Income                                        29275000.0  ...          NaN
# Normalized Income                                    1160943493.1  ...          NaN
# Net Income From Continuing And Discontinued Ope...   1831011000.0  ...          NaN
# Total Expenses                                      15037071000.0  ...          NaN
# Rent Expense Supplemental                                     NaN  ...  201667000.0
# Diluted NI Availto Com Stockholders                  1831011000.0  ...          NaN
# Net Income Common Stockholders                       1831011000.0  ...          NaN
# Otherunder Preferred Stock Dividend                           0.0  ...          NaN
# Net Income                                           1831011000.0  ...          NaN
# Minority Interests                                   -215934000.0  ...          NaN
# Net Income Including Noncontrolling Interests        2046945000.0  ...          NaN
# Net Income Continuous Operations                     2046945000.0  ...          NaN
# Tax Provision                                         222735000.0  ...          NaN
# Pretax Income                                        2269680000.0  ...          NaN
# Other Non Operating Income Expenses                  -154540000.0  ...          NaN
# Special Income Charges                                -26692000.0  ...          NaN
# Other Special Charges                                  26692000.0  ...          NaN
# Restructuring And Mergern Acquisition                         NaN  ... -206061000.0
# Net Non Operating Interest Income Expense           -3436913000.0  ...          NaN
# Total Other Finance Cost                              298747000.0  ...          NaN
# Interest Expense Non Operating                       3167441000.0  ...          NaN
# Interest Income Non Operating                          29275000.0  ...          NaN
# Operating Income                                     4608193000.0  ...          NaN
# Operating Expense                                    2763330000.0  ...          NaN
# Other Operating Expenses                               63267000.0  ...          NaN
# Depreciation And Amortization In Income Statement      67650000.0  ...          NaN
# Depreciation Income Statement                          67650000.0  ...          NaN
# Selling General And Administration                   1924332000.0  ...          NaN
# Selling And Marketing Expense                        1449491000.0  ...          NaN
# General And Administrative Expense                    474841000.0  ...          NaN
# Rent And Landing Fees                                         NaN  ...  201667000.0
# Gross Profit                                         7371523000.0  ...          NaN
# Cost Of Revenue                                     12273741000.0  ...          NaN
# Total Revenue                                       19645264000.0  ...          NaN
# Operating Revenue                                   19645264000.0  ...          NaN
#
# [47 rows x 5 columns]

# %%
k.quarterly_income_stmt
# Out:
#                                                       2024-12-31  ...  2023-06-30
# Tax Effect Of Unusual Items                           36333080.0  ...         NaN
# Tax Rate For Calcs                                          0.34  ...         NaN
# Normalized EBITDA                                   2228282000.0  ...         NaN
# Total Unusual Items                                  106862000.0  ...         NaN
# Total Unusual Items Excluding Goodwill               106862000.0  ...         NaN
# Net Income From Continuing Operation Net Minori...   397698000.0  ...         NaN
# Reconciled Depreciation                             1103818000.0  ...         NaN
# Reconciled Cost Of Revenue                          3136916000.0  ...         NaN
# EBITDA                                              2335144000.0  ...         NaN
# EBIT                                                1231326000.0  ...         NaN
# Net Interest Income                                 -973350000.0  ...         NaN
# Interest Expense                                     837308000.0  ...         NaN
# Interest Income                                       18367000.0  ...  34093000.0
# Normalized Income                                    327169080.0  ...         NaN
# Net Income From Continuing And Discontinued Ope...   397698000.0  ...         NaN
# Total Expenses                                      3844089000.0  ...         NaN
# Rent Expense Supplemental                                    NaN  ...  26282000.0
# Diluted NI Availto Com Stockholders                  397698000.0  ...         NaN
# Net Income Common Stockholders                       397698000.0  ...         NaN
# Otherunder Preferred Stock Dividend                          0.0  ...         NaN
# Net Income                                           397698000.0  ...         NaN
# Minority Interests                                  -145032000.0  ...         NaN
# Net Income Including Noncontrolling Interests        542730000.0  ...         NaN
# Net Income Continuous Operations                     542730000.0  ...         NaN
# Tax Provision                                       -148712000.0  ...         NaN
# Pretax Income                                        394018000.0  ...         NaN
# Other Non Operating Income Expenses                          NaN  ... -31134000.0
# Special Income Charges                               -21680000.0  ...         NaN
# Other Special Charges                                 21680000.0  ...         NaN
# Net Non Operating Interest Income Expense           -973350000.0  ...         NaN
# Total Other Finance Cost                             154409000.0  ...         NaN
# Interest Expense Non Operating                       837308000.0  ...         NaN
# Interest Income Non Operating                         18367000.0  ...  34093000.0
# Operating Income                                    1424130000.0  ...         NaN
# Operating Expense                                    707173000.0  ...         NaN
# Other Operating Expenses                             -98533000.0  ...         NaN
# Depreciation And Amortization In Income Statement     18203000.0  ...         NaN
# Depreciation Income Statement                         18203000.0  ...         NaN
# Selling General And Administration                   599668000.0  ...         NaN
# Selling And Marketing Expense                        438674000.0  ...         NaN
# General And Administrative Expense                   160994000.0  ...         NaN
# Rent And Landing Fees                                        NaN  ...  26282000.0
# Gross Profit                                        2131303000.0  ...         NaN
# Cost Of Revenue                                     3136916000.0  ...         NaN
# Total Revenue                                       5268219000.0  ...         NaN
# Operating Revenue                                   5268219000.0  ...         NaN
#
# [46 rows x 7 columns]

# %%
k.calendar
# Out:
# {'Ex-Dividend Date': datetime.date(2025, 3, 6),
#  'Earnings Date': [datetime.date(2025, 5, 7)],
#  'Earnings High': 0.26822,
#  'Earnings Low': 0.26822,
#  'Earnings Average': 0.26822,
#  'Revenue High': 5140860400,
#  'Revenue Low': 5140860400,
#  'Revenue Average': 5140860400}

# %%
k.options
# Out:
# ()

# %%
opt = mi.option_chain('2026-09-18')
print(opt.calls)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-5cec262cef1b> in <cell line: 0>()
# ----> 1 opt = mi.option_chain('2026-09-18')
#       2 print(opt.calls)
#
# /usr/local/lib/python3.11/dist-packages/yfinance/ticker.py in option_chain(self, date, tz)
#      88                 self._download_options()
#      89             if date not in self._expirations:
# ---> 90                 raise ValueError(
#      91                     f"Expiration `{date}` cannot be found. "
#      92                     f"Available expirations are: [{', '.join(self._expirations)}]")
#
# ValueError: Expiration `2026-09-18` cannot be found. Available expirations are: []

# %%
PARAMOS NA AULA #078
